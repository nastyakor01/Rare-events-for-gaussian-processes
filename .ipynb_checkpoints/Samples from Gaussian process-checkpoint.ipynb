# %%
import numpy as np
import scipy.spatial
import matplotlib.pyplot as plt 
import random 
import math
import cmath
#from scipy.misc import derivative
import sympy

# %% [markdown]
# # Solution 1

# %%
def get_cov(f, points1, points2):
    """Return covariance matrix for the sets of points given according to covariance function f"""
    size1 = points1.shape[0]
    size2 = points2.shape[0]
    cov = np.empty((size1, size2)) 
    for i in range(size1):
        for j in range(size2):
            cov[i, j] = f(points1[i], points2[j])
    return cov

# %%
# examples of covariance functions 

def K_Linear(s,t):
    return abs(s-t)

def Sinc(s, t):
    return np.sinc(s-t)

def K_Wiener(s, t):
    return min(s, t)

def K_RBF(s, t):
    return np.exp(-0.5 * abs(s-t)**2)

def K_brownian_bridge(s, t):
    return min(s, t) - s*t

def exponential(s, t):
    return np.exp(-abs(s-t))

def wave(s,t):
    return np.cos(s-t)

a = np.linspace(2, 5, 4)
b = np.linspace(4, 7, 5)
print(a)
print(b)
get_cov(wave, a, b)
# Out:
# [2. 3. 4. 5.]
# [4.   4.75 5.5  6.25 7.  ]
# array([[-0.41614684, -0.92430238, -0.93645669, -0.44608749,  0.28366219],
#        [ 0.54030231, -0.17824606, -0.80114362, -0.99412968, -0.65364362],
#        [ 1.        ,  0.73168887,  0.0707372 , -0.62817362, -0.9899925 ],
#        [ 0.54030231,  0.96891242,  0.87758256,  0.31532236, -0.41614684]])

# %%
Sinc(4, 4)
# Out:
# 1.0

# %%
# examples of mean functions 
def square(s):
    return s*s

def linear(s):
    return s

def zero(s):
    return 0

# %%
def simulate_GP(mean_function, cov_function, nb_of_samples, number_of_functions, left_border, right_border, ls = True):
    points = np.linspace(left_border, right_border, nb_of_samples)
    Σ = get_cov(cov_function, points, points)
    mean_vals = [mean_function(point) for point in points]
    ys = np.random.multivariate_normal(
                                       mean_vals,
                                       cov=Σ,
                                       size=number_of_functions)
    fig = plt.figure(figsize=(12, 6), dpi=80)
    
    for i in range(number_of_functions):
        if ls:
            plt.plot(points, ys[i])
            plt.plot(points, np.zeros_like(points), color = 'green') 
        #else:
        #    plt.plot(points, ys[i], ls = 'None')
        #plt.scatter(points, ys[i])      
    return ys, fig

# %%
a = simulate_GP(zero, Sinc, 200, 2, 0, 30)

# %%
a = simulate_GP(zero, exponential, 1000, 3, 0, 10)

# %%
a = simulate_GP(zero, Sinc, 1000, 1, 0, 100000000000)

# %% [markdown]
# The more samples, the bigger time of work. Not depending on a kernel chosen. However, when covariance matrix is small enough (less or equal to 1000x1000), algorythm works fast even on big time intervals.

# %%
def prime(f,x):
    e = 10e-8
    return (f(x+e) - f(x-e) )/(2*e)
   
def prime_prime(f, x):
    e = 10e-4
    return ( f(x+e) - 2*f(x) + f(x-e) )/e/e

# %%
def cube(x):
    return x*x*x

prime_prime(cube, 3)
# Out:
# 18.000000000739647

# %%
def E(cov_function):
    r = lambda x: cov_function(0, x) # функция ковариации 
    
    deriv = -prime_prime(r, 0) # -вторая производная
    alfa = np.sqrt(deriv/(r(0)+10e-8))
    E_zeros = 1/np.pi * alfa # считаю среднее число нулей по формуле
        
    return E_zeros

# %%
# функуия для срвнения чисел 
def cmp(a, b): 
    if a > b:
        return 1
    elif a < b:
        return -1
    else:
        return 0


def intersections(mean_function, cov_function, nb_of_samples, number_of_functions, left_border, right_border, ls = True):
    zeros = np.zeros(number_of_functions) # будущее кол-во нулей по всем функциям 
    Y, _ = simulate_GP(mean_function, cov_function, nb_of_samples, number_of_functions, left_border, right_border, ls)
    size = Y.shape[1]
    
    # считаю кол-во нулей
    for j in range(number_of_functions): # если 2 соседних значения разных знаков, то между ними ноль
        pairs = [(Y[j][i], Y[j][i+1]) for i in range(size - 1)]  # буду проверять каждую пару значений 
        for (a,b) in pairs:
            if cmp(a, 0) != cmp(b, 0):
                zeros[j] += 1
    
    E_zeros = E(cov_function) * (right_border - left_border) # считаю среднее число нулей по формуле
    
    # и округляю до ближайшего целого 
    if np.ceil(E_zeros) - E_zeros > E_zeros - np.floor(E_zeros): 
        E_zeros = np.floor(E_zeros)
    else:
        E_zeros = np.ceil(E_zeros)
    
    #plt.figure(figsize = (10, 5), dpi=80)
    #plt.hist(zeros, edgecolor='white')
    #print('E_zeros:',E_zeros)
    #print(zeros)
    return zeros, E_zeros

# %%
intersections(zero, Sinc, 200, 2, 0, 30)
# Out:
# (array([19., 17.]), 17.0)

# %%
intersections(zero, Sinc, 200, 100000, 0, 30, ls=False)
# Out:
# E_zeros: 17.0

# %%
intersections(zero, Sinc, 1000, 100000, 0, 100, ls=False)
# Out:
# E_zeros: 58.0

# %%
intersections(zero, Sinc, 1000, 100000, 0, 1000, ls=False)
# Out:
# E_zeros: 577.0

# %%
zeros, E_zeros = intersections(zero, exponential, 100, 10, 0, 10, ls=True)
plt.figure(figsize = (10, 5), dpi=80)
plt.hist(zeros, edgecolor='white')
print('E_zeros:',E_zeros)
print(zeros)
# Out:
# E_zeros: 142.0
# [ 8.  9. 13. 17. 15. 16. 23. 21. 15.  8.]

# %%
# Здесь хочу выводить данные  в следующем виде:
# на каждой картинке график P(кол-во нулей / T > E(T=1) + e) в зависимости от эпсилон. 
# В одной строке графики для фиксированного временного интервала T и разных ковариаций. Разные строчки для разных значений T.

from collections import Counter

T = [10, 100, 400, 1000] #временные интервалы
kernel = [Sinc, K_RBF, wave] # ковариации
kernel_names = ["Sinc", "RBF", "wave"]

fig, axs = plt.subplots(4, 3, figsize=(20, 20))
for i in range(len(T)):
    eps = [n/T[i] for n in range(100)] 
    for j in range(len(kernel)):
        P = np.zeros(len(eps))
        zeros, _ = intersections(zero, kernel[j], T[i]*5, 1000, 0, T[i], ls = False) 
        for idx,e in enumerate(eps):
            cnt = 0
            for k in range(len(zeros)):
                if abs(zeros[k]/T[i] - E(kernel[j])) > e:
                    P[idx] += 1            
        P = P/1000
        axs[i, j].plot(eps, P)
        axs[i, j].set_title(f'{T[i]},{kernel_names[j]}')

# %%
plt.close('all')

Eps = [0.001, 0.01, 0.05]#, 0.1] # epsilon
kernel = [Sinc, K_RBF, wave] # covariance functions
kernel_names = ["Sinc", "RBF", "wave"]
T = [n for n in range(110, 130)] # time intervals 

fig, axs = plt.subplots(len(Eps), len(kernel), figsize=(20, 20))
for i in range(len(Eps)):
    for j in range(len(kernel)):
        P = np.zeros(len(T))
        for idx, t in enumerate(T):
            zeros, _ = intersections(zero, kernel[j], t*5, 1000, 0, t, ls = False) 
            cnt = 0
            for k in range(len(zeros)):
                if zeros[k]/t - E(kernel[j]) > Eps[i]:
                    P[idx] += 1
        P += 10e-30            
        P = np.log(P/1000)
        axs[i, j].plot(T, P/t)
        axs[i, j].set_title(f'{Eps[i]},{kernel_names[j]}')

# %% [markdown]
# # Solution 1.5

# %%
# Gaussian process posterior
def Gaussian_Posterior(X1, y1, X2, kernel_func):
    """
    Calculate the posterior mean and covariance matrix for y2
    based on the corresponding input X2, the observations (y1, X1), 
    and the prior kernel function.
    """
    # Kernel of the observations
    N = X1.shape[0]
    add = np.eye(N)
    Σ11 = get_cov(kernel_func, X1, X1) + add*10e-8
    # Kernel of observations vs to-predict
    Σ12 = get_cov(kernel_func, X1, X2)
    # Solve
    solved = scipy.linalg.solve(Σ11, Σ12, assume_a='pos').T
    # Compute posterior mean
    μ2 = solved @ y1
    # Compute the posterior covariance
    Σ22 = get_cov(kernel_func, X2, X2)
    Σ2 = Σ22 - (solved @ Σ12)
    return μ2, Σ2  # mean, covariance

# %%
def Simulate_Posterior(mean_function, cov_function, nb_of_samples, number_of_functions, left_border, right_border):
    """Create number_of_samples gaussian values on interval
       [right_border, left_border + right_border]
       according to prior distribution of the previous
       values, generated by means of Simulate_GP. """
    
    # create initial values using solution 1
    X1 = np.linspace(left_border, right_border, nb_of_samples)
    y1, fig = simulate_GP(mean_function, cov_function, nb_of_samples, number_of_functions, left_border, right_border, ls = False)
    
    # samples for new values
    X2 = np.linspace(left_border, right_border, nb_of_samples) + (right_border - left_border)/(2*nb_of_samples -2)
    X = np.sort(np.hstack((X1, X2)))
    y2 = np.zeros_like(y1)
    for i in range(number_of_functions):
        #compute posterior distribution 
        μ2, Σ2 = Gaussian_Posterior(X1, y1[i], X2, cov_function)
        #generate new samples
        y2[i] = np.random.multivariate_normal(μ2, cov=Σ2)
        y = []  
        for j in range(y2.shape[1]):
            y.append(y1[i][j])
            y.append(y2[i][j])

        plt.plot(X, y, figure = fig)
       # plt.scatter(X, y)
    plt.show()

# %%
Simulate_Posterior(zero, Sinc, 90, 4, 0, 30)

# %%
def Posterior(mean_function, cov_function, nb_of_samples, number_of_functions, left_border, right_border, iterations, ls = True):
    """Create number_of_samples gaussian values on interval
       [right_border, left_border + right_border]
       according to prior distribution of the previous
       values, generated by means of Simulate_GP. """
    
    delta = (right_border - left_border) / (iterations+1)
    
    y = np.zeros((iterations+1, nb_of_samples))
    # create initial values using solution 1
    y1, fig = simulate_GP(mean_function, cov_function, nb_of_samples, number_of_functions, left_border, left_border+delta, ls = False)
        
    final_y = [[] for func in range(number_of_functions)]
    for func in range(number_of_functions): 
        X1 = np.linspace(left_border, left_border + delta, nb_of_samples)
        np.delete(X1, 0)
        y[0] = y1[func]
        tmp_y1 = y1[func]
        for it in range(iterations):
            X2 = np.linspace(left_border + delta*(it+1), left_border + delta*(it+2), nb_of_samples)
            np.delete(X2, 0)
            #compute posterior distribution 
            μ2, Σ2 = Gaussian_Posterior(X1, tmp_y1, X2, cov_function)
            #generate new samples
            y[it+1] = np.random.multivariate_normal(μ2, cov=Σ2)
            X1 = X2
            tmp_y1 = y[it+1]
            
        X = np.linspace(left_border, right_border, nb_of_samples*(iterations+1))  
        for j in range(nb_of_samples):
            for it in range (iterations+1):
                final_y[func].append(y[it, j])
        if ls:
            plt.plot(X, final_y[func], figure = fig)
        
    if ls:
        plt.plot(X, np.zeros_like(X), color = 'green')     
        plt.show() 
    return final_y, fig

# %% [markdown]
# Вот здесь вызываю для интервала [0, 30]. Если nb_of_sambles хотя бы 40, все в порядке. Если 30, то уже появляются заломы, как будто в каких-то точках по 2 значения.

# %%
a = Posterior(zero, K_RBF, 100, 1, 0, 30, 1)

# %%
def post_intersections(mean_function, cov_function, nb_of_samples, number_of_functions, left_border, right_border, iterations, ls = True):
    zeros = np.zeros(number_of_functions) # будущее кол-во нулей по всем функциям 
    Y, _ = Posterior(mean_function, cov_function, nb_of_samples, number_of_functions, left_border, right_border, iterations, ls)
    size = len(Y[0])
    
    # считаю кол-во нулей
    for j in range(number_of_functions): # если 2 соседних значения разных знаков, то между ними ноль
        pairs = [(Y[j][i], Y[j][i+1]) for i in range(size - 1)]  # буду проверять каждую пару значений 
        for (a,b) in pairs:
            if cmp(a, 0) != cmp(b, 0):
                zeros[j] += 1
    
    
    
    r = lambda x: cov_function(0, x) # функция ковариации 
    
    deriv = -prime_prime(r, 0) # -вторая производная
    alfa = np.sqrt(deriv/(r(0)+10e-8))
    E_zeros = 1/np.pi * alfa * (right_border - left_border) # считаю среднее число нулей по формуле
    
    # и округляю до ближайшего целого 
    if np.ceil(E_zeros) - E_zeros > E_zeros - np.floor(E_zeros): 
        E_zeros = np.floor(E_zeros)
    else:
        E_zeros = np.ceil(E_zeros)
    
    #plt.figure(figsize = (10, 5), dpi=80)
    #plt.hist(zeros, edgecolor='white')
    return zeros, E_zeros

# %%
post_intersections(zero, K_RBF, 30, 2, 0, 30, 100)
# Out:
# (array([240., 240.]), 10.0)

# %%
T = [10, 100, 400]#, 1000] #временные интервалы
kernel = [Sinc, K_Wiener, K_RBF, exponential, wave] # ковариации
kernel_names = ["Sinc",  "RBF", "wave"]
eps = [n for n in range(10)] 

fig, axs = plt.subplots(3, 5, figsize=(20, 20))
for i in range(3):
    for j in range(3):
        P = np.zeros(len(eps))
        zeros, E_zeros = post_intersections(zero, kernel[j], int(T[i]*3/2), 1000, 0, T[i], 1, ls = False) 
        
#        D = Counter(zeros) # словарь, где ключи -- всевозможные числа в zeros, a значение по ключу -- кол-во функций с таким числом нулей
        for idx,e in enumerate(eps):
            cnt = 0
            for k in range(len(zeros)):
                if abs(zeros[k]-E_zeros) > e:
                    P[idx] += 1
        P = P/1000
        axs[i, j].plot(eps, P) 
        axs[i, j].set_title(f'{T[i]},{kernel_names[j]}')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-223-b99c8ee57fab> in <module>
#       8     for j in range(3):
#       9         P = np.zeros(len(eps))
# ---> 10         zeros, E_zeros = post_intersections(zero, kernel[j], int(T[i]*3/2), 1000, 0, T[i], 1, ls = False)
#      11
#      12 #        D = Counter(zeros) # словарь, где ключи -- всевозможные числа в zeros, a значение по ключу -- кол-во функций с таким числом нулей
#
# <ipython-input-178-bfe9fa9ce460> in post_intersections(mean_function, cov_function, nb_of_samples, number_of_functions, left_border, right_border, iterations, ls)
#       1 def post_intersections(mean_function, cov_function, nb_of_samples, number_of_functions, left_border, right_border, iterations, ls = True):
#       2     zeros = np.zeros(number_of_functions) # будущее кол-во нулей по всем функциям
# ----> 3     Y, _ = Posterior(mean_function, cov_function, nb_of_samples, number_of_functions, left_border, right_border, iterations, ls)
#       4     size = len(Y[0])
#       5
#
# <ipython-input-173-db02b71ffc06> in Posterior(mean_function, cov_function, nb_of_samples, number_of_functions, left_border, right_border, iterations, ls)
#      23             X2 = np.linspace(left_border + delta*(it+1), right_border + delta*(it+1), nb_of_samples)
#      24             #compute posterior distribution
# ---> 25             μ2, Σ2 = Gaussian_Posterior(X1, tmp_y1, X2, cov_function)
#      26             #generate new samples
#      27             y[it+1] = np.random.multivariate_normal(μ2, cov=Σ2)
#
# <ipython-input-15-7005178bbea6> in Gaussian_Posterior(X1, y1, X2, kernel_func)
#       9     N = X1.shape[0]
#      10     add = np.eye(N)
# ---> 11     Σ11 = get_cov(kernel_func, X1, X1) + add*10e-8
#      12     # Kernel of observations vs to-predict
#      13     Σ12 = get_cov(kernel_func, X1, X2)
#
# <ipython-input-69-3bffab136e19> in get_cov(f, points1, points2)
#       6     for i in range(size1):
#       7         for j in range(size2):
# ----> 8             cov[i, j] = f(points1[i], points2[j])
#       9     return cov
#
# <ipython-input-70-664e4468c0d7> in Sinc(s, t)
#       5
#       6 def Sinc(s, t):
# ----> 7     return np.sinc(s-t)
#       8
#       9 def K_Wiener(s, t):
#
# <__array_function__ internals> in sinc(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in sinc(x)
#    3474     """
#    3475     x = np.asanyarray(x)
# -> 3476     y = pi * where(x == 0, 1.0e-20, x)
#    3477     return sin(y)/y
#    3478
#
# <__array_function__ internals> in where(*args, **kwargs)
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x000001A2DECB3B80> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# ~\anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ~\anaconda3\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\anaconda3\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~\anaconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2191                            else suppress())
#    2192                     with ctx:
# -> 2193                         self.figure.draw(renderer)
#    2194
#    2195                     bbox_inches = self.figure.get_tightbbox(
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1861
#    1862             self.patch.draw(renderer)
# -> 1863             mimage._draw_list_compositing_images(
#    1864                 renderer, self, artists, self.suppressComposite)
#    1865
#
# ~\anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2745             renderer.stop_rasterizing()
#    2746
# -> 2747         mimage._draw_list_compositing_images(renderer, self, artists)
#    2748
#    2749         renderer.close_group('axes')
#
# ~\anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1167
#    1168         for tick in ticks_to_draw:
# -> 1169             tick.draw(renderer)
#    1170
#    1171         # scale up the axis label box to also find the neighbors, not
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in draw(self, renderer)
#     289         for artist in [self.gridline, self.tick1line, self.tick2line,
#     290                        self.label1, self.label2]:
# --> 291             artist.draw(renderer)
#     292         renderer.close_group(self.__name__)
#     293         self.stale = False
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\lib\site-packages\matplotlib\text.py in draw(self, renderer)
#     686             posx = float(textobj.convert_xunits(textobj._x))
#     687             posy = float(textobj.convert_yunits(textobj._y))
# --> 688             posx, posy = trans.transform((posx, posy))
#     689             if not np.isfinite(posx) or not np.isfinite(posy):
#     690                 _log.warning("posx and posy should be finite values")
#
# ~\anaconda3\lib\site-packages\matplotlib\transforms.py in transform(self, values)
#    1420
#    1421         # Transform the values
# -> 1422         res = self.transform_affine(self.transform_non_affine(values))
#    1423
#    1424         # Convert the result back to the shape of the input values.
#
# ~\anaconda3\lib\site-packages\matplotlib\transforms.py in transform_affine(self, points)
#    2342     def transform_affine(self, points):
#    2343         # docstring inherited
# -> 2344         return self.get_affine().transform(points)
#    2345
#    2346     def transform_non_affine(self, points):
#
# ~\anaconda3\lib\site-packages\matplotlib\transforms.py in get_affine(self)
#    2369             return self._b.get_affine()
#    2370         else:
# -> 2371             return Affine2D(np.dot(self._b.get_affine().get_matrix(),
#    2372                                    self._a.get_affine().get_matrix()))
#    2373
#
# ~\anaconda3\lib\site-packages\matplotlib\transforms.py in __init__(self, matrix, **kwargs)
#    1844             # A bit faster than np.identity(3).
#    1845             matrix = IdentityTransform._mtx.copy()
# -> 1846         self._mtx = matrix.copy()
#    1847         self._invalid = 0
#    1848
#
# KeyboardInterrupt:

# %%
def Posterior3(mean_function, cov_function, nb_of_samples, number_of_functions, left_border, right_border, iterations, ls = True):
    """Create number_of_samples gaussian values on interval
       [left_border, right_border]
       according to prior distribution of the previous
       values, generated by means of Simulate_GP. """
    
    len_interval = (right_border - left_border) / (iterations+1)
    delta = len_interval/(nb_of_samples - 1)

    final_y = np.zeros((number_of_functions, (iterations+1)*nb_of_samples))
    # create initial values using solution 1
    X1 = np.linspace(left_border, left_border+len_interval, nb_of_samples)
    y1, fig = simulate_GP(mean_function, cov_function, nb_of_samples, number_of_functions, left_border, left_border+len_interval, ls = False)
    
    for func in range(number_of_functions): 
        y = np.zeros((iterations+1, nb_of_samples))
        X = np.zeros((iterations+1, nb_of_samples))
        y[0,:] = y1[func]
        X[0,:] = X1
        for it in range(1, iterations+1):
            X2 = np.linspace(left_border + len_interval*it, left_border + len_interval*(it+1), nb_of_samples)
            #compute posterior distribution 
            μ2, Σ2 = Gaussian_Posterior(X[it-1,:], y[it-1,:], X2, cov_function)
            #generate new samples
            y[it, :] = np.random.multivariate_normal(μ2, cov=Σ2)
            X[it, :] = X2
            
        X = np.reshape(X,((iterations+1)*nb_of_samples,))  
        final_y[func] = np.reshape(y,((iterations+1)*nb_of_samples,))
        if ls:       
            plt.plot(X, final_y[func], figure = fig, marker=".")
            plt.plot(X, np.zeros_like(X), color = 'green')     
         
    if ls:
        plt.show() 
    return final_y, fig

# %%
Posterior3(zero, K_RBF, 10, 1, 0, 3, 3)
# Out:
# (array([[-0.27148894, -0.12894824,  0.01023403,  0.14356501,  0.26860873,
#           0.38297786,  0.48433785,  0.57043309,  0.63914086,  0.68855394,
#           0.68776097,  0.71643565,  0.72402822,  0.71065417,  0.67720071,
#           0.62532194,  0.55737408,  0.47629262,  0.38541941,  0.28829184,
#           0.28817804,  0.18823018,  0.08873471, -0.00733458, -0.09736592,
#          -0.17913588, -0.25080447, -0.31088418, -0.35819973, -0.39184836,
#          -0.3924823 , -0.41361244, -0.42174833, -0.41738148, -0.40124073,
#          -0.37425837, -0.33755105, -0.29241282, -0.24031458, -0.18290392]]),
#  <Figure size 960x480 with 1 Axes>)
